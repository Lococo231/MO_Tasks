# %% [markdown]
# <a href="https://colab.research.google.com/github/Lococo231/MO_Tasks/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # МЛ Практика 1
# ## Обзор занятий: Чем предстоит заниматься
# Цели сессии:
#
# 1. Ознакомление с основными понятиями машинного обучения и структурой практических занятий.
# 2. Представление доступных наборов данных для последующих упражнений.
# 3. Формирование списка участников и распределение ролей (при необходимости).
# 4. Практическое освоение методов описательного анализа данных.
# 5. Понимание типов данных и их важности в контексте машинного обучения.
# План занятий:
#
# 1. Введение и обзор целей курса.
# 2. Представление наборов данных.
# 3. Формирование списка студентов.
# 4. Совместный разбор выбранного набора данных с обсуждением вопросов.
# 5. Задача 1: Описание набора данных и определение типов данных.
# 6. Пример статистического разбора на основе wine.csv.
# 7. Обсуждение типов переменных и их определения по статистике.
# 8. Вопросы и ответы, обсуждение домашних заданий.

# %% [markdown]
# # Наборы данных по вариантам

# %% [markdown]
# Примеры наборов данных

# %% [markdown]
# 1. https://www.kaggle.com/datasets/nabeelqureshitiii/student-performance-dataset
# 2. https://www.kaggle.com/datasets/navjotkaushal/coffee-sales-dataset
# 3. https://www.kaggle.com/datasets/shamimhasan8/education-inequality-data
# 4. https://www.kaggle.com/datasets/adilshamim8/student-depression-dataset
# 5. https://www.kaggle.com/datasets/navjotkaushal/employees-dataset
# 6. https://www.kaggle.com/datasets/abolfazlchanbary81/hearth
# 7. https://www.kaggle.com/datasets/uciml/student-alcohol-consumption
# 8. https://www.kaggle.com/datasets/uom190346a/sleep-health-and-lifestyle-dataset
# 9. https://www.kaggle.com/datasets/lainguyn123/student-performance-factors
# 10. https://www.kaggle.com/datasets/benroshan/factors-affecting-campus-placement
# 11. https://www.kaggle.com/datasets/datascientistanna/customers-dataset

# %% [markdown]
# ## Описание:
# В этом разделе вы загрузите набор данных wine.csv, ознакомитесь с его структурой и проведёте первичный обзор.

# %%
# установка зависимостей
# !pip install pandas matplotlib seaborn
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# импортируем библиотеки
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Описание:
# В этом разделе вы загрузите набор данных wine.csv, ознакомитесь с его структурой и проведёте первичный обзор.

# %%
PATH_TO_FILE: str = '/content/dataset.csv' # Загрузка набора данных
## p.s. в левой панеле нажать на папку и перетащить туда файл,
## а wince.csv заменить на свой вариант (ПКМ -> копировать путь)

df = pd.read_csv(PATH_TO_FILE) # функция превращение данных из CSV в DataFrame

# %%
# вывод датафрейма
df # p.s. обычно переменную с набором данных называют df, придерживайтесь этого наименования в дальнейшем
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# 1                   6                       60             8       Normal
# 2                   6                       60             8       Normal
# 3                   4                       30             8        Obese
# 4                   4                       30             8        Obese
# ..                ...                      ...           ...          ...
# 369                 9                       75             3   Overweight
# 370                 9                       75             3   Overweight
# 371                 9                       75             3   Overweight
# 372                 9                       75             3   Overweight
# 373                 9                       75             3   Overweight
#
#     Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0           126/83          77         4200            NaN
# 1           125/80          75        10000            NaN
# 2           125/80          75        10000            NaN
# 3           140/90          85         3000    Sleep Apnea
# 4           140/90          85         3000    Sleep Apnea
# ..             ...         ...          ...            ...
# 369         140/95          68         7000    Sleep Apnea
# 370         140/95          68         7000    Sleep Apnea
# 371         140/95          68         7000    Sleep Apnea
# 372         140/95          68         7000    Sleep Apnea
# 373         140/95          68         7000    Sleep Apnea
#
# [374 rows x 13 columns]

# %%
# Вывод первых 5 строк
df.head()

# вывод 5 последних строк
#df.tail()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# 1         125/80          75        10000            NaN
# 2         125/80          75        10000            NaN
# 3         140/90          85         3000    Sleep Apnea
# 4         140/90          85         3000    Sleep Apnea

# %%
# Информация о наборе данных
df.info() # инфо о датасете название колонки, сколько не пропущенных, дефолтный тип данных
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
# Статистический разбор
df.describe() # include=all (вывод включая категориальные)
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# 25%                  45.000000      4.000000   68.000000   5600.000000
# 50%                  60.000000      5.000000   70.000000   7000.000000
# 75%                  75.000000      7.000000   72.000000   8000.000000
# max                  90.000000      8.000000   86.000000  10000.000000

# %%
# преобразование в категориальные
# df.columnName = df.columnName.astype('category')
# or
# df['column Name'] = df['column Name'].astype('category')

# %%
# Вывод колонок в наборе данных
df.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder'],
#       dtype='object')

# %% [markdown]
# ## Определение типов переменных

# %%
# Список столбцов и их типов данных
print(df.dtypes)
# Out:
# Person ID                    int64
# Gender                      object
# Age                          int64
# Occupation                  object
# Sleep Duration             float64
# Quality of Sleep             int64
# Physical Activity Level      int64
# Stress Level                 int64
# BMI Category                object
# Blood Pressure              object
# Heart Rate                   int64
# Daily Steps                  int64
# Sleep Disorder              object
# dtype: object

# %% [markdown]
# - Числовые переменные обычно имеют тип int64 или float64.
# - Категориальные переменные могут иметь тип object или int (например метки класса)

# %% [markdown]
# ## Статистический разбор данных

# %% [markdown]
# 1. **Посчитайте количество уникальных значений для каждой переменной:**

# %%
# Количество уникальных значений
for column in df.columns:
    print(f'{column}: {df[column].nunique()} уникальных значений')
# Out:
# Person ID: 374 уникальных значений
# Gender: 2 уникальных значений
# Age: 31 уникальных значений
# Occupation: 11 уникальных значений
# Sleep Duration: 27 уникальных значений
# Quality of Sleep: 6 уникальных значений
# Physical Activity Level: 16 уникальных значений
# Stress Level: 6 уникальных значений
# BMI Category: 4 уникальных значений
# Blood Pressure: 25 уникальных значений
# Heart Rate: 19 уникальных значений
# Daily Steps: 20 уникальных значений
# Sleep Disorder: 2 уникальных значений

# %% [markdown]
# **⏰ задача**
#
# Определить типы переменных
# - номинальные переменные (не имеют порядка и сравнения)
# - порядковые пиеременные (имеют порядок, но не имеют смысла мат операции)
# - числовые непрерывные переменные (имеют порядок, есть смысл мат операций)
#
# Вывести статистику для числовых и для категоиральных перменных раздельно.
#
# p.s. если существует несколько гипотез к какому типу относительно одна и та же переменной - объяснить почему

# %% [markdown]
# ## **4. Визуализация распределения переменных**
#
# ### **Описание:**
# Создайте визуализации для понимания распределения числовых и категориальных переменных.
#
# ### **Шаги:**

# %% [markdown]
# 1. **Гистограмма для числовых переменных:**

# %%
sns.histplot(data=df, x='Age', kde=True, hue='Sleep Disorder')
plt.title('Распределение Age')
plt.xlabel('Age')
plt.ylabel('Частота')
plt.show()
# ниже код для оптимизации вывода всех числовых переменных
#num_cols = df.select_dtypes(include='float').columns # если есть int чиловая переменная либо + ['col1', 'col2'], либо такие колонки преобразовать во flaot
#fig, axes = plt.subplots(1, len(num_cols), figsize=(6 * len(num_cols), 4))

#for ax, col in zip(axes, num_cols):
#    sns.histplot(df[col], kde=True, ax=ax)
#    ax.set_title(f'Распределение {col}')
#    ax.set_xlabel(col)
#    ax.set_ylabel('Частота')

#plt.tight_layout()
#plt.show()

# %% [markdown]
# **задача ⏰**
#
# Описать вывод графиков.
# - Является ли распределение нормальным или отлично от него? - Распределение не нормальное, очень низкое p-значение.
# - Концентрация большинства значений - 35-50 лет.
# - если есть категориальная переменная, то с помощью параметры hue попробовать предсказать значение категориальный переменной (пример с диоксидом серы и типом вина)
#
# p.s. 3-5 самых показательных примеров.

# %% [markdown]
# 2. **Столбчатая диаграмма для категориальной переменной `Class`:**

# %%
sns.countplot(data=df, x='Gender', hue='Sleep Disorder')
plt.title('Распределение пола с учетом нарушений сна')
plt.xlabel('Пол')
plt.ylabel('Количество')
plt.show()

# %% [markdown]
# **задача ⏰**
#
# Описать вывод графиков.
# - в каких значениях концентрируентся переменная? - 35-50 лет
# - если есть категориальная переменная, то с помощью параметры hue попробовать предсказать значение категориальный переменной (пример с диоксидом серы и типом вина) - распределение меняется по категориям (нарушения сна)

# %% [markdown]
# **Боксплот для числовой переменной:**

# %%
sns.boxplot(data=df, x='Occupation', y='Heart Rate', hue='Sleep Disorder')
plt.title('Частота сердцебиения по профессиям и нарушениям сна')
plt.xlabel('Профессия')
plt.ylabel('Частота сердцебиения')
plt.xticks(rotation=45)
plt.show()

sns.boxplot(data=df, x='Occupation', y='Heart Rate')
plt.title('Частота сердцебиения по профессиям и нарушениям сна')
plt.xlabel('Профессия')
plt.ylabel('Частота сердцебиения')
plt.xticks(rotation=45)
plt.show()
#num_cols = df.select_dtypes(include='float').columns # если есть int чиловая переменная либо + ['col1', 'col2'], либо такие колонки преобразовать во flaot
#fig, axes = plt.subplots(1, len(num_cols), figsize=(6 * len(num_cols), 4))

#for ax, col in zip(axes, num_cols):
#    sns.boxplot(df[col], ax=ax)
#    ax.set_title(f'Распределение {col}')
#    ax.set_xlabel(col)
#    ax.set_ylabel('Частота')

#plt.tight_layout()
#plt.show()

# %% [markdown]
# **задача ⏰**
#
# Описать вывод графиков.
# Тут получилась частота сердцебиения по профессиям, по некоторым получлось хорошо, по некоторым плохо.
# - Есть ли выбросы? - да
# - если есть категориальная переменная, то с помощью параметры hue попробовать предсказать значение категориальный переменной (пример с диоксидом серы и типом вина). Определить различия по медиане - При апноэ сердечный ритм выше.

# %% [markdown]
# **Постройте корреляционную матрицу для всех числовых переменных и визуализируйте её с помощью тепловой карты:**

# %%
# Только числовые переменные
df_num = df.select_dtypes(include=['number'])

corr = df_num.corr()

sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Корреляционная матрица')
plt.show()

print('Без корреляции (<0.1):')
print((corr.abs() < 0.1).stack()[lambda x: x].index.tolist())

print('\nСильная положительная (>=0.7):')
print((corr >= 0.7).stack()[lambda x: x].index.tolist())

print('\nСлабая (0.1-0.7):')
print(((corr.abs() >= 0.1) & (corr.abs() < 0.7)).stack()[lambda x: x].index.tolist())
# Out:
# Без корреляции (<0.1):
# [('Person ID', 'Daily Steps'), ('Age', 'Daily Steps'), ('Sleep Duration', 'Daily Steps'), ('Quality of Sleep', 'Daily Steps'), ('Physical Activity Level', 'Stress Level'), ('Stress Level', 'Physical Activity Level'), ('Heart Rate', 'Daily Steps'), ('Daily Steps', 'Person ID'), ('Daily Steps', 'Age'), ('Daily Steps', 'Sleep Duration'), ('Daily Steps', 'Quality of Sleep'), ('Daily Steps', 'Heart Rate')]
#
# Сильная положительная (>=0.7):
# [('Person ID', 'Person ID'), ('Person ID', 'Age'), ('Age', 'Person ID'), ('Age', 'Age'), ('Sleep Duration', 'Sleep Duration'), ('Sleep Duration', 'Quality of Sleep'), ('Quality of Sleep', 'Sleep Duration'), ('Quality of Sleep', 'Quality of Sleep'), ('Physical Activity Level', 'Physical Activity Level'), ('Physical Activity Level', 'Daily Steps'), ('Stress Level', 'Stress Level'), ('Heart Rate', 'Heart Rate'), ('Daily Steps', 'Physical Activity Level'), ('Daily Steps', 'Daily Steps')]
#
# Слабая (0.1-0.7):
# [('Person ID', 'Sleep Duration'), ('Person ID', 'Quality of Sleep'), ('Person ID', 'Physical Activity Level'), ('Person ID', 'Stress Level'), ('Person ID', 'Heart Rate'), ('Age', 'Sleep Duration'), ('Age', 'Quality of Sleep'), ('Age', 'Physical Activity Level'), ('Age', 'Stress Level'), ('Age', 'Heart Rate'), ('Sleep Duration', 'Person ID'), ('Sleep Duration', 'Age'), ('Sleep Duration', 'Physical Activity Level'), ('Sleep Duration', 'Heart Rate'), ('Quality of Sleep', 'Person ID'), ('Quality of Sleep', 'Age'), ('Quality of Sleep', 'Physical Activity Level'), ('Quality of Sleep', 'Heart Rate'), ('Physical Activity Level', 'Person ID'), ('Physical Activity Level', 'Age'), ('Physical Activity Level', 'Sleep Duration'), ('Physical Activity Level', 'Quality of Sleep'), ('Physical Activity Level', 'Heart Rate'), ('Stress Level', 'Person ID'), ('Stress Level', 'Age'), ('Stress Level', 'Heart Rate'), ('Stress Level', 'Daily Steps'), ('Heart Rate', 'Person ID'), ('Heart Rate', 'Age'), ('Heart Rate', 'Sleep Duration'), ('Heart Rate', 'Quality of Sleep'), ('Heart Rate', 'Physical Activity Level'), ('Heart Rate', 'Stress Level'), ('Daily Steps', 'Stress Level')]

# %% [markdown]
# **если ValueError**

# %%
# Если будут ошибки ValueError из-за could not conver string to float
df = df.drop('colName', axis=1)
# найти колонку, из-за которой ничего не получается,
# можно найти по object из df.info()

# %% [markdown]
# **задача ⏰**
#
# Интерпертировать полученный результат:
# - Какие переменные не коррелируют? Количество шагов в день и его номер, возраст, длительность сна, качество сна и сердцебиение; Уровень физ. активности и уровень стресса.
# - Какие переменные имеют сильную положительную корреляцию? Длительность сна и его качество, уровень стресса и частота серцебиения (чуть чуть не дотягивет) и количетсво шагов в день и уровень физ. активности (естественно).
# - Какие переменные имеют сильную слабую корреляцию? как я понял, это обратная корреляция? качество сна и уровень стресса, длительность сна и уровень стресса.
#
# Также вывел через print, но получилось неважно.
#
# p.s. сильная корреляция считаем abs(corr_coef) >= 0.7
